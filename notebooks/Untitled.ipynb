# %%
import sys
sys.path.append('.../src')
import cifrado
cifrado.cifrado_cesar("hola",3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('.../src')
# ----> 3 import cifrado
#       4 cifrado.cifrado_cesar("hola",3)
#
# ModuleNotFoundError: No module named 'cifrado'
