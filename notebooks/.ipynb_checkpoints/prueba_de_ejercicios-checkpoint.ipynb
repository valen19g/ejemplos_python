# %%
import sys
sys.path.append('../src')
import ejercicio1
# Out:
# 23
# 137
# 5.96
# Special cases aren't special enough to break the rules.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way
# Although that way may not be obvious at first unless you're
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good
# Namespaces are one honking great idea -- let's do more of

# %%
import ejercicio2
# Out:
# duracion total 46m 53s
# Stairway to Heaven   8:02
# ------------
# Imagine   3:07
# ----------

# %%
import ejercicio3
# Out:
# ingrese palabra considerada spoliers separadas por coma a
# La película sigue * un grupo de astronautas que viajan * Marte en una misión de rescate. El capitán Torres lidera al equipo * través de tormentas solares y fallos en el sistema de navegación. Al llegar * Marte descubren que la base está abandonada y los suministros destruidos. Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver * la Tierra en una cápsula de emergencia. El final revela que Torres sobrevivió gracias * un pasaje secreto.

# %%
import ejercicio4
# Out:
# ingrese mail a
# a es invalido

# %%
import ejercicio5
# Out:
# ingrese el peso del paquete (kg) 5
# ingrese la zona del envio (local/regional/nacional local
# Costo de envio: 1000

# %%
import ejercicio6
# Out:
# Hashtags trending (más de una aparición)
# #Programación: 3
# #Python: 3
# #InteligenciaArtificial: 3
# #SerieAdicta: 2
# #Motivación: 2

# %%
import ejercicio7
# Out:
# ingrese nombres separados por ,  juan,pepe,luca
# juan -> luca
# luca -> juan

# %%
import ejercicio8

# %%
import ejercicio9
# Out:
# ingrese mensaje hola
# ingrese el desplazamiento 3
# ['h', 'o', 'l', 'a']
# krod

# %%
# Out:
# Registros limpios de alumnos:
# Ana García 9 Aprobado
# Carlos Ruiz 6 Aprobado
# Gabriela Ríos 5 Aprobado
# Laura Méndez 8 Aprobado
# María Fernández 10 Aprobado
# Pedro López 4 Desaprobado
# Sofía Torres 9 Aprobado
# Total de alumnos válidos: 7

# %%
import ejercicio10
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ejercicio10
#
# ModuleNotFoundError: No module named 'ejercicio10'
